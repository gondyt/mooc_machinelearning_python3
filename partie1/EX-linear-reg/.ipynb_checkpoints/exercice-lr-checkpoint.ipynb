# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
plt.style.use('seaborn-dark')
plt.rcParams.update({ 'font.size' : 15, 'xtick.labelsize':15, 'ytick.labelsize':15 })

# %%
hubble = pd.read_csv("hubble_data.csv")

# %%
#x_train = hubble[['distance']][:12]
#x_test = hubble[['distance']][12:]
#y_train = hubble[['recession_velocity']][:12]
#y_test = hubble[['recession_velocity']][12:]

x = hubble[['distance']]
y = hubble[['recession_velocity']]

# %%
reg = LinearRegression()

# %%
reg.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_prediction = reg.predict(x)

# %%
fig = plt.figure()
ax = plt.axes()
plt.scatter(x, y, color='grey', label='Données')
plt.plot(x, y_prediction, color='blue', linewidth=3, label='Prédiction')
ax.set(xlabel="Distance", ylabel="Vitesse de récession")
plt.title("Régression linéaire entre la distance d'une galaxie\nde la Terre et sa vitesse de récession")
plt.legend(loc='lower right', frameon=True)
