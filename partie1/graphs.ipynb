# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-dark')
plt.rcParams.update({ 'font.size' : 15, 'xtick.labelsize':15, 'ytick.labelsize':15 })

# %%
x = np.linspace(0, 10, 1000)

# %%
plt.plot(x, np.sin(x), color='black', label='sin(x)') # param linestyle
plt.axis([0,10, -1,1])
plt.title('My first graph')
plt.legend(loc='lower left')
ax = plt.axes()
ax.set(xlabel='x', ylabel='sin(x)')
# Out:
# /home/tanjoe/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """
# [Text(0, 0.5, 'sin(x)'), Text(0.5, 0, 'x')]

# %%
x1 = np.linspace(1, 10, 50)
dy = 0.8

# %%
y1 = np.sin(x1) + (dy*np.random.randn(50))
plt.errorbar(x1, y1, yerr=dy, fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fig, ax = plt.figure(), plt.axes()
x = np.linspace(1, 10, 1000)

# %%
plt.plot(x, np.sin(x - 0), color='blue', linestyle='solid', label='bleu')
plt.plot(x, np.sin(x - 1), color='g', linestyle='dashed', label='vert')
plt.plot(x, np.sin(x - 2), color='0.75', linestyle='dashdot', label='gris')
plt.plot(x, np.sin(x - 3), color='#FF0000', linestyle='dotted', label='rouge')
plt.axis([-1, 11, -1.5, 1.5])
plt.title('Exemples de fonctionalités Matplotlib')
plt.legend(loc='lower left')

# %%
import seaborn as sb
sb.set()

x = np.linspace(1, 10, 500)
y = np.random.randn(500)
plt.plot(x,y)

# %%
sb.distplot(y, kde=True)

# %%
iris = sb.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sb.pairplot(iris, hue='species', height=2.5)
